# %%
# data visualization library

# %%
# allows creation of statistics graphics

# %%
# THe functionality of seaborn
# allows comparision between multiple variable
# supports multiplots girds
# available univeriate and veriate visualization
# available of different color pelettes to reavel various colors of patterns
# also estimate linear regression autometically

# %%
# Why we use seaborn instead of matplotlib?

# %%
# reasons
# matplotlib settings are defficult to figure outs. seaborn comes with numeriuos customized theme and high level interfaces.
# matplotlib doesn't serve well when it comes with dealing dataframe while seaborn function actually work on dataframe.

# %%
#dependencies of seaborn: matplotlib, numpy, pandas, scipy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import seaborn as sns
# %matplotlib inline

# %%
a= sns.load_dataset('flights')

# %%
a.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
sns.relplot(x='passengers', y='month', data=a)

# %%
sns.relplot(x='passengers', y='month', hue='year', data=a)

# %%
b= sns.load_dataset('tips')
sns.relplot(x='time', y='tip', kind='line', data=b)

# %%
sns.catplot(x='time',y='tip', data=b)

# %%
sns.catplot(x='passengers',y='month', data=a)

# %%
sns.catplot(x='day',y='total_bill', data=b)

# %%
sns.catplot(x='day',y='total_bill', kind='violin', data=b)

# %%
sns.catplot(x='day',y='total_bill', kind='boxen', data=b)

# %%
from scipy import stats

# %%
c=np.random.normal(loc=5, size=100, scale=1)

# %%
sns.distplot(c)

# %%
# bivariete distrubution

# %%
d=pd.read_csv('data.csv')

# %%
d.head()
# Out:
#        city  temp  population
# 0     dhaka    25      120000
# 1    khulna    30     1256677
# 2   jessore    26      456620
# 3  rajshahi    39      565758
# 4  barishal    22      567923

# %%
sns.jointplot(x='temp', y='population', kind='kde',data=d)

# %%
e=sns.load_dataset('iris')
f=sns.FacetGrid(e, col='species')
f.map(plt.hist, 'sepal_length')

# %%
e=sns.load_dataset('flights')
f=sns.PairGrid(e)
f.map(plt.scatter)

# %%
sns.set_style('darkgrid')
e=sns.load_dataset('flights')
f=sns.PairGrid(e)
f.map(plt.scatter)
